# %%
For loop inside For loop

# %%
for i in range(1,10):
    print("* "*i)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * * * *
# * * * * * * * *
# * * * * * * * * *

# %%
for i in range(1,6):
    print(i*"*")
# Out:
# *
# **
# ***
# ****
# *****

# %%
for char in ("python"):
    print('char is' ,char)
# Out:
# char is p
# char is y
# char is t
# char is h
# char is o
# char is n

# %%
for char in ("Python"):
    print()
    print('char is ',char)
    print("main loop")
    print()
    for i in range(6):
        print(f'number is {i}')
# Out:
# char is  P
# main loop
#
# number is 0
# number is 1
# number is 2
# number is 3
# number is 4
# number is 5
#
# char is  y
# main loop
#
# number is 0
# number is 1
# number is 2
# number is 3
# number is 4
# number is 5
#
# char is  t
# main loop
#
# number is 0
# number is 1
# number is 2
# number is 3
# number is 4
# number is 5
#
# char is  h
# main loop
#
# number is 0
# number is 1
# number is 2
# number is 3
# number is 4
# number is 5
#
# char is  o
# main loop
#
# number is 0
# number is 1
# number is 2
# number is 3
# number is 4
# number is 5
#
# char is  n
# main loop
#
# number is 0
# number is 1
# number is 2
# number is 3
# number is 4
# number is 5

# %%
for char in ("python"):
    print('char is ',char)
    for i in range(1,4):
        print("Number is :", i)
        for j in ("Don"):
            print("second char is :", j)
            for k in range(3):
                print("third loop val is :",k)
    print()
# Out:
# char is  p
# Number is : 1
# second char is : D
# third loop val is : 0
# third loop val is : 1
# third loop val is : 2
# second char is : o
# third loop val is : 0
# third loop val is : 1
# third loop val is : 2
# second char is : n
# third loop val is : 0
# third loop val is : 1
# third loop val is : 2
# Number is : 2
# second char is : D
# third loop val is : 0
# third loop val is : 1
# third loop val is : 2
# second char is : o
# third loop val is : 0
# third loop val is : 1
# third loop val is : 2
# second char is : n
# third loop val is : 0
# third loop val is : 1
# third loop val is : 2
# Number is : 3
# second char is : D
# third loop val is : 0
# third loop val is : 1
# third loop val is : 2
# second char is : o
# third loop val is : 0
# third loop val is : 1
# third loop val is : 2
# second char is : n
# third loop val is : 0
# third loop val is : 1
# third loop val is : 2
#
# char is  y
# Number is : 1
# second char is : D
# third loop val is : 0
# third loop val is : 1
# ...
